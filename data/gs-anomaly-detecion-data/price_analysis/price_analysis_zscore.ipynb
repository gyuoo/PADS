# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.ticker import ScalarFormatter, MultipleLocator
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import zscore

# %%
data_route = "C:\\workspace\\project_final\\data\\dataset_sample_10percent.csv"
data = pd.read_csv(data_route, encoding='utf-8')

# %%
# Z-score 기준 이상치 여부를 판단하는 임계값
z_threshold = 3

# 결과를 담을 리스트
outliers_data = []

# Z-score 계산 및 이상치 여부 확인 함수ㅊ
def calculate_z_scores(df, group_column):
    # 그룹 내에서 가격에 대한 Z-score 계산
    df[f'{group_column}_zscore'] = df.groupby(group_column)['price'].transform(lambda x: zscore(x, ddof=0))
    # Z-score가 임계값 이상인 경우 이상치로 간주
    df[f'{group_column}_outlier'] = df[f'{group_column}_zscore'].abs() > z_threshold
    return df

# 기준 컬럼별로 Z-score 계산 및 이상치 판단
data = calculate_z_scores(data, 'cate2_nm')
data = calculate_z_scores(data, 'supplier_code')
data = calculate_z_scores(data, 'class_name')
data = calculate_z_scores(data, 'brand_name')

# %%
data['overall_outlier'] = data['supplier_code_outlier'] & data['cate2_nm_outlier'] & data['class_name_outlier'] & data['brand_name_outlier']
# Out:
#              prd_id                                      view_name cate1_nm  \
# 0        1060200990           해찬솔 통원목 4인용소파 + 1800소파테이블 세트/원목소파/쇼파       가구
# 1        1046158490                    [OF17431P]지나산업 손목밴딩처리 화려한무늬       가구
# 2        1011281663           제니스가구 H1000 허리편안한 마원단 롤팩 토퍼 매트리스(SS)       가구
# 3        1053975280                 [로쏘가구](착불) 뷔엘 원목 6인 식탁 벤치의자 세트       가구
# 4          50573580        이케아 KOLBJORN 콜비에른 수납장 실내외겸용 80x81cm/장식장       가구
# ...             ...                                            ...      ...
# 1591786  1059172756  white race 디자인 하드 폰케 -(하드)갤럭시s21+white ribbon  휴대폰/태블릿
# 1591787  1066350236                      소나 명화구름 인서트케이스-아이폰13MINI1  휴대폰/태블릿
# 1591788  1009287263                         그림의떡 소프트젤리케이스-갤럭시노트8그린  휴대폰/태블릿
# 1591789  1064227039                    헤롱이 피크닉인파리 방탄케이스-아이폰15PRO핑크  휴대폰/태블릿
# 1591790  1064451669                    Doe 도트마일 소프트젤리케이스-갤럭시노트10남색  휴대폰/태블릿
#
#         cate2_nm  cate3_nm  supplier_code   class_name    price  discprice  \
# 0             소파   수납/벤치소파        1001561           소파  2313000    2313000
# 1           수납가구     주방수납장        1022174  타이즈/스타킹/레깅스     8000       8000
# 2           매트리스  슈퍼싱글매트리스        1048198         매트리스   199900     199900
# 3             식탁      식탁세트        1027596         식탁세트   986900     986900
# 4           수납가구     거실장식장        1030023          수납장   183400     183400
# ...          ...       ...            ...          ...      ...        ...
# 1591786   휴대폰케이스         0        1047551     핸드폰 액세서리    15000      15000
# 1591787   휴대폰케이스         0        1047551     핸드폰 액세서리    15000      15000
# 1591788   휴대폰케이스         0        1047551     핸드폰 액세서리     5000       5000
# 1591789   휴대폰케이스         0        1047551     핸드폰 액세서리    10000      10000
# 1591790   휴대폰케이스         0        1047551     핸드폰 액세서리     5000       5000
#
#          buy_count  ...  brand_name  cate2_nm_zscore  cate2_nm_outlier  \
# 0                0  ...    해찬솔원목이야기         0.281786             False
# 1                0  ...    셀러허브 식품샵        -0.497312             False
# 2                1  ...       제니스슬립        -0.406331             False
# 3                0  ...        로쏘가구         0.289569             False
# 4                4  ...         이케아        -0.178079             False
# ...            ...  ...         ...              ...               ...
# 1591786          0  ...       핫트랙스          0.044332             False
# 1591787          0  ...       핫트랙스          0.044332             False
# 1591788          0  ...       핫트랙스         -1.081847             False
# 1591789          0  ...       핫트랙스         -0.518757             False
# 1591790          0  ...       핫트랙스         -1.081847             False
#
#         supplier_code_zscore  supplier_code_outlier  class_name_zscore  \
# 0                   2.411031                  False           0.251007
# 1                  -0.403980                  False          -0.245377
# 2                   0.047426                  False          -0.416801
# 3                   2.048563                  False           0.038765
# 4                   0.800114                  False           0.049414
# ...                      ...                    ...                ...
# 1591786            -0.071883                  False           0.003347
# 1591787            -0.071883                  False           0.003347
# 1591788            -0.251188                  False          -0.821278
# 1591789            -0.161536                  False          -0.408965
# 1591790            -0.251188                  False          -0.821278
#
#          class_name_outlier  brand_name_zscore  brand_name_outlier  \
# 0                     False           1.442929               False
# 1                     False          -0.415844               False
# 2                     False           0.379427               False
# 3                     False           1.877647               False
# 4                     False           0.654445               False
# ...                     ...                ...                 ...
# 1591786               False          -0.071917               False
# 1591787               False          -0.071917               False
# 1591788               False          -0.251228               False
# 1591789               False          -0.161572               False
# 1591790               False          -0.251228               False
#
#          overall_outlier
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 1591786            False
# 1591787            False
# 1591788            False
# 1591789            False
# 1591790            False
#
# [1591791 rows x 23 columns]

# %%
outliers = data[data['overall_outlier'] == True]

# 필요한 컬럼만 선택해서 출력
display(outliers[['prd_id', 'supplier_code', 'cate2_nm', 'class_name', 'brand_name', 
                  'supplier_code_zscore', 'cate2_nm_zscore', 'class_name_zscore', 'brand_name_zscore',
                  'overall_outlier', 'price']])

print(len(outliers)/len(data)*100, "% outlier based on Z-score")
# Out:
#              prd_id  supplier_code   cate2_nm class_name brand_name  \
# 1611     1008984212        1034195         소파         소파      베이직가구
# 3939     1048878201        1037595         의자         의자      무케렌시아
# 4206     1037438760        1020872  DIY/반제품가구       공간박스       오너클랜
# 4457     1048878198        1037595         의자         의자      무케렌시아
# 4897     1003761767        1002315         소파         소파      장수돌침대
# ...             ...            ...        ...        ...        ...
# 1584683  1049563222        1038059  기타휴대폰액세서리         물병       오너클랜
# 1586137  1049524874        1038059  기타휴대폰액세서리         물병       오너클랜
# 1586391  1050648242        1038059  기타휴대폰액세서리   카메라 소품세트       오너클랜
# 1588445    27808695        1031568     휴대폰케이스   핸드폰 액세서리       쇼베뉴엘
# 1591706  1054397122        1038059  기타휴대폰액세서리    기타 사무기기       오너클랜
#
#          supplier_code_zscore  cate2_nm_zscore  class_name_zscore  \
# 1611                 3.052303         5.121591           5.036084
# 3939                 6.933420        26.588531          22.798847
# 4206                15.359703         5.636001           7.454744
# 4457                 7.264238        27.806959          23.846385
# 4897                 3.260549         3.293318           3.228485
# ...                       ...              ...                ...
# 1584683              7.654144         8.603504          10.676011
# 1586137              3.937575         4.431890           5.488016
# 1586391              6.955331         7.819130           3.210371
# 1588445              3.218066        11.486311           8.381539
# 1591706              4.905851         5.518718           3.070315
#
#          brand_name_zscore  overall_outlier     price
# 1611              3.052303             True  12240000
# 3939              6.933420             True  12160000
# 4206             15.553227             True   1435400
# 4457              7.264238             True  12710000
# 4897              3.418362             True   8490000
# ...                    ...              ...       ...
# 1584683           7.558046             True    712900
# 1586137           3.879710             True    380500
# 1586391           6.866422             True    650400
# 1588445           3.211342             True    116600
# 1591706           4.838025             True    467100
#
# [2531 rows x 11 columns]
# 0.15900328623544172 % outlier based on Z-score
